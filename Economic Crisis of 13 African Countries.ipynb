# %% [markdown]
# #### Economic Data (of up to 2014) Insights of 13 African Countries to Identify:
# i) Trends of economic crisis
# ii) Effects of Foreign debt default to a country's economy
# iii) Bank Crisis in Relation to Economic Crisis

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Reading the file
df = pd.read_csv('african_crises.csv')
df
# Out:
#       case  cc3   country  year  systemic_crisis    exch_usd  \
# 0        1  DZA   Algeria  1870                1    0.052264
# 1        1  DZA   Algeria  1871                0    0.052798
# 2        1  DZA   Algeria  1872                0    0.052274
# 3        1  DZA   Algeria  1873                0    0.051680
# 4        1  DZA   Algeria  1874                0    0.051308
# ...    ...  ...       ...   ...              ...         ...
# 1054    70  ZWE  Zimbabwe  2009                1  354.800000
# 1055    70  ZWE  Zimbabwe  2010                0  378.200000
# 1056    70  ZWE  Zimbabwe  2011                0  361.900000
# 1057    70  ZWE  Zimbabwe  2012                0  361.900000
# 1058    70  ZWE  Zimbabwe  2013                0  361.900000
#
#       domestic_debt_in_default  sovereign_external_debt_default  \
# 0                            0                                0
# 1                            0                                0
# ...

# %%
#Getting info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   case                             1059 non-null   int64
#  1   cc3                              1059 non-null   object
#  2   country                          1059 non-null   object
#  3   year                             1059 non-null   int64
#  4   systemic_crisis                  1059 non-null   int64
#  5   exch_usd                         1059 non-null   float64
#  6   domestic_debt_in_default         1059 non-null   int64
#  7   sovereign_external_debt_default  1059 non-null   int64
#  8   gdp_weighted_default             1059 non-null   float64
#  9   inflation_annual_cpi             1059 non-null   float64
#  10  independence                     1059 non-null   int64
#  11  currency_crises                  1059 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['case', 'cc3', 'country', 'year', 'systemic_crisis', 'exch_usd',
#        'domestic_debt_in_default', 'sovereign_external_debt_default',
#        'gdp_weighted_default', 'inflation_annual_cpi', 'independence',
#        'currency_crises', 'inflation_crises', 'banking_crisis'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                                   count          mean            std  \
# case                             1059.0     35.613787      23.692402
# year                             1059.0   1967.767705      33.530632
# systemic_crisis                  1059.0      0.077432       0.267401
# exch_usd                         1059.0     43.140831     111.475380
# domestic_debt_in_default         1059.0      0.039660       0.195251
# sovereign_external_debt_default  1059.0      0.152975       0.360133
# gdp_weighted_default             1059.0      0.006402       0.043572
# inflation_annual_cpi             1059.0  20848.892444  675727.429176
# independence                     1059.0      0.776204       0.416984
# currency_crises                  1059.0      0.132200       0.349847
# inflation_crises                 1059.0      0.129367       0.335765
#
#                                          min          25%         50%  \
# ...

# %%
countries = df['country'].nunique()
countries
# Out:
# 13

# %% [markdown]
# #### 1) Count of crises that African countries have experienced.
# A count of 1 = Economic crisis
# A count of 0 = No economic crisis

# %%
crisis = df.groupby(['country', 'systemic_crisis']).size().unstack().fillna(0)
# crisis['Total'] = crisis.sum(axis = 1)
crisis.sort_values(by = 1, ascending = False)
# Out:
# systemic_crisis               0     1
# country
# Central African Republic   39.0  19.0
# Zimbabwe                   75.0  15.0
# Kenya                      54.0  13.0
# Nigeria                    50.0  10.0
# Egypt                     149.0   6.0
# Tunisia                    70.0   5.0
# Algeria                    81.0   4.0
# Ivory Coast                59.0   4.0
# Zambia                     68.0   4.0
# Morocco                    73.0   2.0
# Angola                     77.0   0.0
# Mauritius                  68.0   0.0
# South Africa              114.0   0.0

# %% [markdown]
# #### A bar plot of the crisis

# %%
crisis.sort_values(by = 1, ascending = False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# Central African Republic (CAR) has had the highest number of system crises(19). South Africa has had no economic crisis.

# %% [markdown]
# ### A trend of Kenya's crisis

# %%
ke = df[(df.country == 'Kenya') & (df.systemic_crisis == 1) & (df.year)]
trend = ke.groupby(['systemic_crisis', 'year']).size()
trend
# Out:
# systemic_crisis  year
# 1                1985    1
#                  1987    1
#                  1989    1
#                  1993    1
#                  1995    1
#                  1997    1
#                  1999    1
# dtype: int64

# %% [markdown]
# Kenya experienced a systemic crisis in the year: 1985, 1987, 1989, 1993, 1995, 1995 and 1999.

# %% [markdown]
# ii) Trends of Sovereign External debt default
# Default = 1
# No default  = 0

# %%
crises = df.groupby(['country', 'sovereign_external_debt_default']).size().unstack().fillna(0)
crises.sort_values(by = 1, ascending = False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# Kenya's Sovereign External debt default

# %%
ke_default = df[(df.country == 'Kenya') & (df.sovereign_external_debt_default == 1) & (df.year)]
default = ke_default.groupby(['sovereign_external_debt_default', 'year']).size()
default
# Out:
# sovereign_external_debt_default  year
# 1                                1995    1
#                                  1997    1
# dtype: int64

# %% [markdown]
# Kenya defaulted on extaernal loan payment in 1995 and 1997

# %% [markdown]
# #### Bank Crises in relation to Economic crisis

# %% [markdown]
# #### Bank crisis

# %%
banks = df.groupby(['country','banking_crisis']).size().unstack()
banks.sort_values(by = 'crisis', ascending = False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# ### Bank crisis in Relation to Economic Crisis

# %%
bank = df.groupby(['country','systemic_crisis', 'banking_crisis']).size().unstack().fillna(0)
bank.sort_values(by = 'crisis', ascending  = False)
# Out:
# banking_crisis                            crisis  no_crisis
# country                  systemic_crisis
# Central African Republic 1                  19.0        0.0
# Zimbabwe                 1                  15.0        0.0
# Nigeria                  1                  10.0        0.0
# Kenya                    1                   8.0        5.0
# Angola                   0                   7.0       70.0
# Egypt                    0                   6.0      143.0
#                          1                   5.0        1.0
# Tunisia                  1                   5.0        0.0
# Zambia                   1                   4.0        0.0
# Ivory Coast              1                   4.0        0.0
# Algeria                  1                   4.0        0.0
# South Africa             0                   3.0      111.0
# Morocco                  1                   2.0        0.0
# Nigeria                  0                   1.0       49.0
# ...
